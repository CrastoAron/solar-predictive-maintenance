# %% [markdown]
# # SolarShield — Notebook 01: Data Preparation (Real ESP32 Dataset)
# **Project**: SolarShield — ML-Driven Predictive Maintenance & Efficiency Analysis
# **College**: St Joseph Engineering College, Mangaluru (VTU)
#
# **Purpose**: Load real ESP32 sensor data from all weeks, merge into one dataset,
# engineer the 12 rolling features, synthesize labels, and save data/solar_features.csv

# %%
import pandas as pd
import numpy as np
import os
import glob

RANDOM_STATE = 42
RATED_POWER  = 12.0
WINDOW_MINUTES = 30

os.makedirs('../data', exist_ok=True)
os.makedirs('../ml_models', exist_ok=True)

print('Libraries loaded.')

# %% [markdown]
# ## 1. Load and merge all weekly CSV files

# %%
data_dir = '../data'
all_files = glob.glob(os.path.join(data_dir, 'Week*', 'Day*.csv'))
print(f'Found {len(all_files)} CSV files')

dfs = []
for f in sorted(all_files):
    try:
        temp_df = pd.read_csv(f)
        temp_df['source_file'] = os.path.basename(f)
        dfs.append(temp_df)
    except Exception as e:
        print(f'Skipping {f}: {e}')

df = pd.concat(dfs, ignore_index=True)
print(f'Combined shape: {df.shape}')
print('Columns:', df.columns.tolist())
df.head()

# %% [markdown]
# ## 2. Clean and prepare raw columns

# %%
df['DATE_TIME'] = pd.to_datetime(df['timestamp'], errors='coerce')
df.dropna(subset=['DATE_TIME'], inplace=True)
df.dropna(subset=['voltage_V', 'current_A', 'temp_C', 'light_lux'], inplace=True)

df['voltage']     = df['voltage_V'].clip(lower=0)
df['current']     = df['current_A'].clip(lower=0)
df['power']       = (df['voltage'] * df['current']).clip(lower=0)
df['lux']         = df['light_lux'].clip(lower=0)
df['temperature'] = df['temp_C'].clip(-10, 80)

hum_col = next((c for c in df.columns if 'humid' in c.lower()), None)
df['humidity'] = df[hum_col].clip(0, 100) if hum_col else 65.0

df = df.sort_values('DATE_TIME').reset_index(drop=True)

print(f'Clean shape: {df.shape}')
df[['DATE_TIME','voltage','current','power','lux','temperature','humidity']].head()

# %% [markdown]
# ## 3. Rolling 30-minute feature engineering

# %%
cadence_sec = df['DATE_TIME'].diff().median().total_seconds()
window_rows = max(2, int((WINDOW_MINUTES * 60) / cadence_sec))
print(f'Detected cadence: {cadence_sec/60:.1f} min, rolling window = {window_rows} rows')

def rolling_mean(s, w): return s.rolling(w, min_periods=1).mean()
def rolling_std(s, w):  return s.rolling(w, min_periods=1).std().fillna(0)

feat = pd.DataFrame()
feat['DATE_TIME']            = df['DATE_TIME']
feat['voltage_mean']         = rolling_mean(df['voltage'],     window_rows)
feat['voltage_std']          = rolling_std(df['voltage'],      window_rows)
feat['current_mean']         = rolling_mean(df['current'],     window_rows)
feat['current_std']          = rolling_std(df['current'],      window_rows)
feat['power_mean']           = rolling_mean(df['power'],       window_rows)
feat['power_std']            = rolling_std(df['power'],        window_rows)
feat['lux_mean']             = rolling_mean(df['lux'],         window_rows)
feat['temperature_mean']     = rolling_mean(df['temperature'], window_rows)
feat['humidity_mean']        = rolling_mean(df['humidity'],    window_rows)

elapsed_min = max((cadence_sec * (window_rows - 1)) / 60, 1)
feat['power_rate_of_change']   = df['power'].diff(window_rows - 1).fillna(0) / elapsed_min
feat['voltage_rate_of_change'] = df['voltage'].diff(window_rows - 1).fillna(0) / elapsed_min
feat['efficiency_ratio']       = feat['power_mean'] / (feat['lux_mean'] / 1000 + 0.001)

print('Features engineered. Shape:', feat.shape)
feat.head()

# %% [markdown]
# ## 4. Synthesise labels

# %%
def assign_fault(er):
    if er < 1.5:  return 2
    if er < 3.0:  return 1
    return 0

feat['fault_class']      = feat['efficiency_ratio'].apply(assign_fault)
feat['efficiency_score'] = (df['power'] / RATED_POWER * 100).clip(0, 100).values
feat['maintenance_days'] = [max(0, min(365, 90 - (i // 144))) for i in range(len(feat))]

print('Label distribution (fault_class):')
print(feat['fault_class'].value_counts().sort_index().rename({0:'Normal',1:'Degraded',2:'Fault'}))
print('\nefficiency_score stats:'); print(feat['efficiency_score'].describe())
print('\nmaintenance_days stats:'); print(feat['maintenance_days'].describe())

# %% [markdown]
# ## 5. Save final dataset

# %%
FEATURE_ORDER = [
    'voltage_mean', 'voltage_std',
    'current_mean', 'current_std',
    'power_mean',   'power_std',
    'lux_mean',
    'temperature_mean', 'humidity_mean',
    'power_rate_of_change', 'voltage_rate_of_change',
    'efficiency_ratio'
]
TARGET_COLS = ['fault_class', 'efficiency_score', 'maintenance_days']

final_df = feat[FEATURE_ORDER + TARGET_COLS].dropna().reset_index(drop=True)
print(f'Final dataset shape: {final_df.shape}')

final_df.to_csv('../data/solar_features.csv', index=False)
print('Saved to data/solar_features.csv')
final_df.head()

# %%
assert list(final_df.columns[:12]) == FEATURE_ORDER, 'Feature order mismatch!'
assert final_df['fault_class'].isin([0,1,2]).all(), 'Invalid fault_class!'
assert final_df['efficiency_score'].between(0,100).all(), 'efficiency_score out of range!'
assert final_df['maintenance_days'].between(0,365).all(), 'maintenance_days out of range!'
print('All sanity checks passed!')
print(f'Total rows ready for training: {len(final_df)}')
